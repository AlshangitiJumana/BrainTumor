# %% [markdown]
# <div style="
#     background-color: #60A5FA;
#     padding: 20px;
#     border-radius: 0px;
#     box-shadow: 0 4px 12px rgba(96, 165, 250, 0.7);
#     color: white;
#     font-weight: bold;
#     font-size: 24px;
#     font-family: 'Times New Roman', Times, serif;
#     text-align: center;
# ">
#     YOLO versions comparison!
# </div>

# %% [markdown]
# <div style="
#     background-color: #60A5FA;
#     padding: 20px;
#     border-radius: 0px;
#     box-shadow: 0 4px 12px rgba(96, 165, 250, 0.7);
#     color: white;
#     font-size: 16px;
#     font-family: 'Times New Roman', Times, serif;
#     text-align: left;
# ">
#     Libraries
# </div>

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.patches as patches
import cv2
import math
import os
import zipfile
import random
import shutil
import Augmentor
from sklearn.model_selection import train_test_split
from ultralytics import YOLO
from PIL import Image
from IPython.display import display

# %% [markdown]
# <div style="
#     background-color: #60A5FA;
#     padding: 20px;
#     border-radius: 0px;
#     box-shadow: 0 4px 12px rgba(96, 165, 250, 0.7);
#     color: white;
#     font-size: 16px;
#     font-family: 'Times New Roman', Times, serif;
#     text-align: left;
# ">
#     YOLOv8
# </div>

# %% [markdown]
# <span style="color: #60A5FA; font-weight: bold;">Small</span>

# %%
# Load a COCO-pretrained YOLO8n model
yolo_btd_model = YOLO('yolov8s.yaml')

# Train the model on the COCO8 example dataset for 50 epochs
yolo_btd_model_results = yolo_btd_model.train(data=r"C:\Users\AMoma\computer_vision\brain_tumor_CV_project\brain_tumor_dataset.yaml", epochs=50, batch=16)
# Out:
# New https://pypi.org/project/ultralytics/8.3.109 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.75  Python-3.9.21 torch-2.6.0+cu118 CUDA:0 (NVIDIA GeForce RTX 4070, 12282MiB)
# ...

# %% [markdown]
# <div style="
#     background-color: #60A5FA;
#     padding: 20px;
#     border-radius: 0px;
#     box-shadow: 0 4px 12px rgba(96, 165, 250, 0.7);
#     color: white;
#     font-size: 16px;
#     font-family: 'Times New Roman', Times, serif;
#     text-align: left;
# ">
#     YOLOv11
# </div>

# %% [markdown]
# <span style="color: #60A5FA; font-weight: bold;">Nano</span>

# %%
# Load a COCO-pretrained YOLO11n model
model = YOLO("yolo11n.pt")

# Train the model on the COCO8 example dataset for 50 epochs
results = model.train(data=r"C:\Users\AMoma\computer_vision\brain_tumor_CV_project\brain_tumor_dataset.yaml", epochs=50, batch=16)
# Out:
# New https://pypi.org/project/ultralytics/8.3.107 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.75  Python-3.9.21 torch-2.6.0+cu118 CUDA:0 (NVIDIA GeForce RTX 4070, 12282MiB)
# ...

# %% [markdown]
# <span style="color: #60A5FA; font-weight: bold;">Small</span>

# %%
# Load a COCO-pretrained YOLO11s model
model = YOLO("yolo11s.pt")

# Train the model on the COCO8 example dataset for 50 epochs
results = model.train(data=r"C:\Users\AMoma\computer_vision\brain_tumor_CV_project\brain_tumor_dataset.yaml", epochs=50, batch=16)
# Out:
# New https://pypi.org/project/ultralytics/8.3.107 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.75  Python-3.9.21 torch-2.6.0+cu118 CUDA:0 (NVIDIA GeForce RTX 4070, 12282MiB)
# ...

# %% [markdown]
# <span style="color: #60A5FA; font-weight: bold;">Medium</span>

# %%
# Load a COCO-pretrained YOLO11m model
model = YOLO("yolo11m.pt")

# Train the model on the COCO8 example dataset for 50 epochs
results = model.train(data=r"C:\Users\AMoma\computer_vision\brain_tumor_CV_project\brain_tumor_dataset.yaml", epochs=50, batch=16)
# Out:
# ...
# 100%|██████████| 38.8M/38.8M [00:03<00:00, 10.4MB/s]
# New https://pypi.org/project/ultralytics/8.3.107 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.75  Python-3.9.21 torch-2.6.0+cu118 CUDA:0 (NVIDIA GeForce RTX 4070, 12282MiB)
# ...

# %% [markdown]
# <div style="
#     background-color: #60A5FA;
#     padding: 20px;
#     border-radius: 0px;
#     box-shadow: 0 4px 12px rgba(96, 165, 250, 0.7);
#     color: white;
#     font-size: 16px;
#     font-family: 'Times New Roman', Times, serif;
#     text-align: left;
# ">
#     YOLOv5
# </div>

# %% [markdown]
# <span style="color: #60A5FA; font-weight: bold;">Nano</span>

# %%
# Load a COCO-pretrained YOLO5n model
model = YOLO("yolov5nu.pt")

# Train the model on the COCO8 example dataset for 50 epochs
results = model.train(data=r"C:\Users\AMoma\computer_vision\brain_tumor_CV_project\brain_tumor_dataset.yaml", epochs=50, batch=16)
# Out:
# ...
# 100%|██████████| 5.31M/5.31M [00:01<00:00, 3.29MB/s]
# New https://pypi.org/project/ultralytics/8.3.107 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.75  Python-3.9.21 torch-2.6.0+cu118 CUDA:0 (NVIDIA GeForce RTX 4070, 12282MiB)
# ...

# %% [markdown]
# <span style="color: #60A5FA; font-weight: bold;">Small</span>

# %%
# Load a COCO-pretrained YOLO5s model
model = YOLO("yolov5s.pt")

# Train the model on the COCO8 example dataset for 50 epochs
results = model.train(data=r"C:\Users\AMoma\computer_vision\brain_tumor_CV_project\brain_tumor_dataset.yaml", epochs=50, batch=16)
# Out:
# PRO TIP  Replace 'model=yolov5s.pt' with new 'model=yolov5su.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...
# 100%|██████████| 17.7M/17.7M [00:02<00:00, 6.25MB/s]
# New https://pypi.org/project/ultralytics/8.3.107 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.75  Python-3.9.21 torch-2.6.0+cu118 CUDA:0 (NVIDIA GeForce RTX 4070, 12282MiB)
# ...

# %% [markdown]
# <span style="color: #60A5FA; font-weight: bold;">Medium</span>

# %%
# Load a COCO-pretrained YOLO5m model
model = YOLO("yolov5m.pt")

# Train the model on the COCO8 example dataset for 50 epochs
results = model.train(data=r"C:\Users\AMoma\computer_vision\brain_tumor_CV_project\brain_tumor_dataset.yaml", epochs=50, batch=16)
# Out:
# PRO TIP  Replace 'model=yolov5m.pt' with new 'model=yolov5mu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...
# 100%|██████████| 48.2M/48.2M [00:05<00:00, 9.39MB/s]
# New https://pypi.org/project/ultralytics/8.3.107 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.75  Python-3.9.21 torch-2.6.0+cu118 CUDA:0 (NVIDIA GeForce RTX 4070, 12282MiB)
# ...

# %% [markdown]
# <div style="
#     background-color: #60A5FA;
#     padding: 20px;
#     border-radius: 0px;
#     box-shadow: 0 4px 12px rgba(96, 165, 250, 0.7);
#     color: white;
#     font-size: 16px;
#     font-family: 'Times New Roman', Times, serif;
#     text-align: left;
# ">
#     YOLOv10
# </div>

# %% [markdown]
# <span style="color: #60A5FA; font-weight: bold;">Nano</span>

# %%
# Load a COCO-pretrained YOLO10n model
model = YOLO("yolov10n.pt")

# Train the model on the COCO8 example dataset for 50 epochs
results = model.train(data=r"C:\Users\AMoma\computer_vision\brain_tumor_CV_project\brain_tumor_dataset.yaml", epochs=50, batch=16)
# Out:
# New https://pypi.org/project/ultralytics/8.3.109 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.75  Python-3.9.21 torch-2.6.0+cu118 CUDA:0 (NVIDIA GeForce RTX 4070, 12282MiB)
# ...

# %% [markdown]
# <span style="color: #60A5FA; font-weight: bold;">Small</span>

# %%
# Load a COCO-pretrained YOLO10s model
model = YOLO("yolov10s.pt")

# Train the model on the COCO8 example dataset for 50 epochs
results = model.train(data=r"C:\Users\AMoma\computer_vision\brain_tumor_CV_project\brain_tumor_dataset.yaml", epochs=50, batch=16)
# Out:
# New https://pypi.org/project/ultralytics/8.3.109 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.75  Python-3.9.21 torch-2.6.0+cu118 CUDA:0 (NVIDIA GeForce RTX 4070, 12282MiB)
# ...

# %% [markdown]
# <span style="color: #60A5FA; font-weight: bold;">Medium</span>

# %%
# Load a COCO-pretrained YOLO10m model
model = YOLO("yolov10m.pt")

# Train the model on the COCO8 example dataset for 50 epochs
results = model.train(data=r"C:\Users\AMoma\computer_vision\brain_tumor_CV_project\brain_tumor_dataset.yaml", epochs=50, batch=16)
# Out:
# ...
# 100%|██████████| 32.1M/32.1M [00:06<00:00, 5.01MB/s]
# New https://pypi.org/project/ultralytics/8.3.109 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.75  Python-3.9.21 torch-2.6.0+cu118 CUDA:0 (NVIDIA GeForce RTX 4070, 12282MiB)
# ...
